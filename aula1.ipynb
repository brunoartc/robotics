# %%
# Entregável 1 - visão computacional

# %%
# %matplotlib inline
import cv2
from matplotlib import pyplot as plt
import numpy as np
import time as t
print ("OpenCV Version : %s " % cv2.__version__)
# Out:
# OpenCV Version : 3.4.0

# %% [markdown]
# # Equalização de histograma

# %%
rintin = cv2.imread("RinTinTin.jpg")

# %%
rintin.shape
# Out:
# (240, 320, 3)

# %%
rintin_gray = cv2.cvtColor(rintin, cv2.COLOR_RGB2GRAY)

# %%
rintin_gray.shape
# Out:
# (240, 320)

# %%
plt.imshow(rintin_gray, cmap="Greys_r", vmin=0, vmax=255)

# %%
hist,bins = np.histogram(rintin_gray.flatten(),256,[0,256])

cdf = hist.cumsum()
cdf_normalized = cdf * hist.max()/ cdf.max()

plt.plot(cdf_normalized, color = 'b')
plt.hist(rintin_gray.flatten(),256,[0,256], color = 'r')
plt.xlim([0,256])
plt.legend(('cdf','histogram'), loc = 'upper left')
plt.show()

# %%
maxi=0
mini=255

for i in rintin_gray:
    if i.min()<mini:
        mini=i.min()
    if i.max()>maxi:
        maxi=i.max()
        
print(mini)
print(maxi)
# Out:
# 8
# 58

# %%
def pixel(x):
    y=(255*(x-8))/50
    return y


for i in rintin_gray:
    for a in range(len(i)):
        i[a]=pixel(i[a])

# %%
plt.hist(rintin_gray.flatten(),256,[0,256], color = 'r')
plt.xlim([0,256])
plt.legend(('cdf','histogram'), loc = 'upper left')
plt.show()

# %%
plt.imshow(rintin_gray, cmap="Greys_r", vmin=0, vmax=255)

# %% [markdown]
# ## Atividade 1
#
# Realize as seguintes atividades:
#
# 1. O histograma fornecido aproveita bem as faixas de cores?
# 2. Equalize o histograma de maneira que a cumulativa seja uma função linear na diagonal do gráfico
# 3. Plote a imagem desenhada

# %% [markdown]
# ## Atividade 2

# %% [markdown]
# Leia com a OpenCV a figura abaixo:
#
# ![](hall_box_battery1.jpg)
#
# Separe os canais  R e B das imagens e analise seus histogramas.
#
# 1. A partir dos canais R e B e da análise do histograma é possível identificar a caixa vermelha e a bateria azul?
#
# 1. Crie uma imagem numpy em que somente os pixels da caixa vermelha estão brancos e faça seu plot aqui

# %%
hall_box = cv2.imread("hall_box_battery1.jpg")

# %%
print(hall_box[0])
# Out:
# [[ 81 120 152]
#  [ 84 123 155]
#  [ 84 122 154]
#  ...
#  [113 116 114]
#  [112 115 113]
#  [112 115 113]]

# %%
b=cv2.cvtColor(hall_box, cv2.COLOR_BGR2RGB)

# %%
print(b[0])
# Out:
# [[152 120  81]
#  [155 123  84]
#  [154 122  84]
#  ...
#  [114 116 113]
#  [113 115 112]
#  [113 115 112]]

# %%
ver=[]
for col in b:
    for lista in col:
        for red in lista:
            ver.append(red)
            break

# %%
verde=[]
for col in b:
    for lista in col:
        verde.append(lista[1])
        break

# %%
azul=[]
for col in b:
    for lista in col:
        azul.append(lista[2])
        break

# %%
print(max(azul))
# Out:
# 141

# %%
plt.hist(azul,bins=100,color="b")
plt.show()

# %%
plt.hist(ver,bins=50,color="r")
plt.show()

# %%
plt.hist(verde,bins=50,color="g")
plt.show()

# %%
novo=cv2.cvtColor(hall_box, cv2.COLOR_BGR2HSV)

# for linha in novo:
#     for pixel in linha:
# #         if pixel[1]<=60 and pixel[2]<=65 and pixel[0]>=90:
#         if pixel[0]<=10:
#             pixel[0]=255
#             pixel[1]=255
#             pixel[2]=255

# %%
plt.imshow(novo, aspect="auto")
